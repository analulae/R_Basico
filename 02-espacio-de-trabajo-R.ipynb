# %% [markdown]
# # Espacio de trabajo:

# %% [markdown]
# # RStudio

# %% [markdown]
#    Vamos a comenzar por familiarizarnos con el espacio de trabajo, conozcamos RStudio.
#
#    Consta de 4 ventanas que le dan seguimiento a los datos introducidos y a los resultados, permiten una mejor visualización y manejo de los mismos.
#
#    RStudio funciona como

# %% [markdown]
# ![001%20Pantalla%20completa.png](attachment:001%20Pantalla%20completa.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_12-33-34.png](attachment:Captura%20de%20pantalla_2017-08-09_12-33-34.png)

# %% [markdown]
# Atajo a la Consola: **Ctrl + 2**

# %% [markdown]
# # Ventana Source

# %% [markdown]
# La ventana de **source** es nuestro editor, aquí se crea el fichero o script (pueden abrirse varios y trabajar con ellos al mismo tiempo en la consola). En este espacio se escribe y corre el código dependiendo de nuestras necesidades, línea a línea, por bloque o completo (estos resultados aparecerán en la consola).

# %% [markdown]
# ![003%20Script.png](attachment:003%20Script.png)

# %% [markdown]
# Dentro de la ventana **Source** se puede:
# + Guardar el trabajo realizado en el script (Ícono del disco)
# + Encontrar y reemplazar (Ícono de lupa)
# + Ejecutar la línea del código dónde está posicionado el cursor (Ícono Run)
# + Ejecutar un bloque del código (Ícono Run o **Ctrl + Enter** con el área a correr resaltada)
# + Ejecutar todo el fichero (Ícono Source)
# + Insertar comentarios con **#** delante del texto

# %% [markdown]
# Este espacio es muy útil para desarrollar código en R, ya que como otros editores presenta:
# + Inserción automática de paréntesis
# + Identación automática, facilitando la lectura del código
# + Completado automático (nombres de variables o funciones)
# + Información sobre los argumentos de las funciones
# + Coloreado de palabras para identificar funciones, input, comentarios, etc.

# %% [markdown]
# Atajo para ventana Source:**Ctrl + 1**

# %% [markdown]
# # Ventana Environment

# %% [markdown]
# Esta ventana muestra todos los objetos guardados en memoria bajo tres tipos principales:
# + Data
# + Values
# + Functions
#
# Muestra sus características e incluso permite su edición.

# %% [markdown]
# ![004%20Enviroment.png](attachment:004%20Enviroment.png)

# %% [markdown]
# Cuando hacemos doble click sobre una función, se abre un visor en la ventana **Source** con el código fuente.
# Si el objeto es una base de datos, es presentada como una hoja de cálculo y puede además ser editada.

# %% [markdown]
# Esta ventana además nos permite importar conjuntos de datos, en los formatos: CSV, Excel, SPSS, SAS y Stata

# %% [markdown]
# Atajo para ventana Environment: **Ctrl + 4**

# %% [markdown]
# # Ventana History

# %% [markdown]
# Aquí se guarda un historial de todos los comandos que han sido ejecutados en la consola, pudiendo ser reusados.

# %% [markdown]
# ![005%20History.png](attachment:005%20History.png)

# %% [markdown]
# + Uno o varios comandos (presionando la techa Shift) pueden ser seleccionados y ejecutados en la consola pulsando Enter.
# + El comando puede ser enviado a la Consola (Botón **To Console**) para ser ejecutado, o a un script (Botón **To Source**).
# + Se pueden eliminar comandos con la tecla Supr o con el botón correspondiente, o borrar completamente el historial con la escoba.

# %% [markdown]
# Atajo para ventana History: **Ctrl + 5**

# %% [markdown]
# # Ventana Files

# %% [markdown]
# Muestra el contenido de la carpeta de trabajo actual. Al hacer clic sobre un script de la lista, se abrirá en la ventana Source.

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_12-40-06.png](attachment:Captura%20de%20pantalla_2017-08-09_12-40-06.png)

# %% [markdown]
# Atajo para ventana Files: **Ctrl + 6**

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_13-06-21.png](attachment:Captura%20de%20pantalla_2017-08-09_13-06-21.png)

# %% [markdown]
# Atajo para ventana Plots: **Ctrl + 7**

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_13-08-03.png](attachment:Captura%20de%20pantalla_2017-08-09_13-08-03.png)

# %% [markdown]
# Atajo para ventana Packages: **Ctrl + 8**

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_13-09-34.png](attachment:Captura%20de%20pantalla_2017-08-09_13-09-34.png)

# %% [markdown]
# Atajo para ventana Help: **Ctrl + 9**

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_14-59-51.png](attachment:Captura%20de%20pantalla_2017-08-09_14-59-51.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-01-56.png](attachment:Captura%20de%20pantalla_2017-08-09_15-01-56.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-03-53.png](attachment:Captura%20de%20pantalla_2017-08-09_15-03-53.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-04-58.png](attachment:Captura%20de%20pantalla_2017-08-09_15-04-58.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-06-25.png](attachment:Captura%20de%20pantalla_2017-08-09_15-06-25.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-08-32.png](attachment:Captura%20de%20pantalla_2017-08-09_15-08-32.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-09-15.png](attachment:Captura%20de%20pantalla_2017-08-09_15-09-15.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-10-39.png](attachment:Captura%20de%20pantalla_2017-08-09_15-10-39.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-13-19.png](attachment:Captura%20de%20pantalla_2017-08-09_15-13-19.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-14-10.png](attachment:Captura%20de%20pantalla_2017-08-09_15-14-10.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-14-59.png](attachment:Captura%20de%20pantalla_2017-08-09_15-14-59.png)

# %% [markdown]
# ![Captura%20de%20pantalla_2017-08-09_15-15-42.png](attachment:Captura%20de%20pantalla_2017-08-09_15-15-42.png)

# %% [markdown]
# # Instalación de paquetes
